# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load dataset

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %% [markdown]
# ### first 5 rows

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure_in_months  \
# 0  7590-VHVEG  Female              0     Yes         No                 1
# 1  5575-GNVDE    Male              0      No         No                34
# 2  3668-QPYBK    Male              0      No         No                 2
# 3  7795-CFOCW    Male              0      No         No                45
# 4  9237-HQITU  Female              0      No         No                 2
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# ### Last 5 Rows

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure_in_months  \
# 7038  6840-RESVB    Male              0     Yes        Yes                24
# 7039  2234-XADUH  Female              0     Yes        Yes                72
# 7040  4801-JZAZL  Female              0     Yes        Yes                11
# 7041  8361-LTMKD    Male              1     Yes         No                 4
# 7042  3186-AJIEK    Male              0      No         No                66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
# ...

# %% [markdown]
# ### check null values

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure_in_months    0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ### Statical form of data

# %%
df.describe()
# Out:
#        SeniorCitizen  tenure_in_months  MonthlyCharges
# count    7043.000000       7043.000000     7043.000000
# mean        0.162147         32.371149       64.761692
# std         0.368612         24.559481       30.090047
# min         0.000000          0.000000       18.250000
# 25%         0.000000          9.000000       35.500000
# 50%         0.000000         29.000000       70.350000
# 75%         0.000000         55.000000       89.850000
# max         1.000000         72.000000      118.750000

# %% [markdown]
# ### Shape of data

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# ### info of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure_in_months  7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ### To check number of unique values in dataset

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure_in_months      73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %% [markdown]
# ### check unique value in each columns

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['SeniorCitizen'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Partner'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Dependents'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['tenure_in_months'].unique()
# Out:
# array([ 1, 34,  2, 45,  8, 22, 10, 28, 62, 13, 16, 58, 49, 25, 69, 52, 71,
#        21, 12, 30, 47, 72, 17, 27,  5, 46, 11, 70, 63, 43, 15, 60, 18, 66,
#         9,  3, 31, 50, 64, 56,  7, 42, 35, 48, 29, 65, 38, 68, 32, 55, 37,
#        36, 41,  6,  4, 33, 67, 23, 57, 61, 14, 20, 53, 40, 59, 24, 44, 19,
#        54, 51, 26,  0, 39], dtype=int64)

# %%
df['PhoneService'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['MultipleLines'].unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
df['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['OnlineBackup'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
df['DeviceProtection'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['TechSupport'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['StreamingTV'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['PaymentMethod'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
df['MonthlyCharges'].unique()
# Out:
# array([29.85, 56.95, 53.85, ..., 63.1 , 44.2 , 78.7 ])

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# ### conversion of data types

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %% [markdown]
# ### Drop the Columns

# %%
df.drop(columns='customerID', inplace=True)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure_in_months PhoneService  \
# 0  Female              0     Yes         No                 1           No
# 1    Male              0      No         No                34          Yes
# 2    Male              0      No         No                 2          Yes
# 3    Male              0      No         No                45           No
# 4  Female              0      No         No                 2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# ### Here data is cleaned

# %% [markdown]
# ### Data PreProcessing

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
le = LabelEncoder()

df['gender'] = le.fit_transform(df['gender'])

# %%
df['Partner'] = le.fit_transform(df['Partner'])

# %%
df['Dependents'] = le.fit_transform(df['Dependents'])

# %%
df['PhoneService'] = le.fit_transform(df['PhoneService'])

# %%
 df['MultipleLines'] = le.fit_transform(df['MultipleLines'])

# %%
  df['InternetService'] = le.fit_transform(df['InternetService'])

# %%
df['OnlineSecurity'] = le.fit_transform(df['OnlineSecurity'])

# %%
df['OnlineBackup'] = le.fit_transform(df['OnlineBackup'])

# %%
df.nunique()
# Out:
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure_in_months      73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6530
# Churn                  2
# dtype: int64

# %%
df['DeviceProtection'] = le.fit_transform(df['DeviceProtection'])

# %%
df['TechSupport'] = le.fit_transform(df['TechSupport'])

# %%
df['StreamingTV'] = le.fit_transform(df['StreamingTV'])

# %%
df['StreamingMovies'] = le.fit_transform(df['StreamingMovies'])

# %%
df['Contract'] = le.fit_transform(df['Contract'])

# %%
df['PaperlessBilling'] = le.fit_transform(df['PaperlessBilling'])

# %%
df['PaymentMethod'] = le.fit_transform(df['PaymentMethod'])

# %%
df['Churn'] = le.fit_transform(df['Churn'])

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure_in_months  PhoneService  \
# 0       0              0        1           0                 1             0
# 1       1              0        0           0                34             1
# 2       1              0        0           0                 2             1
# 3       1              0        0           0                45             0
# 4       0              0        0           0                 2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %% [markdown]
# #### Here complete Data preProcessing

# %%
matrix_relation = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(matrix_relation, annot=True, fmt='.2f', cmap='coolwarm', square=True, linewidths=2)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ###  Here gender, MutipileLineService, StreamingTV, Streaming Movies,are not closely related to data
# #### that's why we reomove these columns

# %%
df.drop(["gender", "PhoneService", "MultipleLines", "StreamingTV", "StreamingMovies"], axis = 1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SeniorCitizen     7043 non-null   int64
#  1   Partner           7043 non-null   int32
#  2   Dependents        7043 non-null   int32
#  3   tenure_in_months  7043 non-null   int64
#  4   InternetService   7043 non-null   int32
#  5   OnlineSecurity    7043 non-null   int32
#  6   OnlineBackup      7043 non-null   int32
#  7   DeviceProtection  7043 non-null   int32
#  8   TechSupport       7043 non-null   int32
#  9   Contract          7043 non-null   int32
#  10  PaperlessBilling  7043 non-null   int32
#  11  PaymentMethod     7043 non-null   int32
#  12  MonthlyCharges    7043 non-null   float64
#  13  TotalCharges      7032 non-null   float64
#  14  Churn             7043 non-null   int32
# dtypes: float64(2), int32(11), int64(2)
# memory usage: 522.9 KB

# %% [markdown]
# ### Make a future class

# %%
X = df.drop(["Churn"], axis = 1)
y = df["Churn"]

# %% [markdown]
# ### Spilit data into train and test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %% [markdown]
# ### ANN Model

# %%
from tensorflow.keras import layers, models
     

ann_model = models.Sequential([
      layers.Dense(7000, input_dim=X_train.shape[1], activation='relu'),
      layers.Dense(700, activation = "relu"),
      layers.Dense(1, activation='sigmoid')
])
     

ann_model.compile(optimizer= "adam", loss = "mean_squared_error", metrics=["accuracy"])
     

history = ann_model.fit(
    X_train,
    y_train,
    epochs = 5,
    batch_size = 25,
    validation_split = 0.2
)
# Out:
# Epoch 1/5
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 23s 115ms/step - accuracy: 0.5653 - loss: 0.4050 - val_accuracy: 0.7507 - val_loss: 0.1895
# Epoch 2/5
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 22s 123ms/step - accuracy: 0.7293 - loss: 0.1978 - val_accuracy: 0.7507 - val_loss: 0.1876
# Epoch 3/5
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 23s 125ms/step - accuracy: 0.7251 - loss: 0.1997 - val_accuracy: 0.7507 - val_loss: 0.1882
# Epoch 4/5
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 41s 126ms/step - accuracy: 0.7249 - loss: 0.1995 - val_accuracy: 0.7507 - val_loss: 0.1886
# Epoch 5/5
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 23s 124ms/step - accuracy: 0.7249 - loss: 0.1994 - val_accuracy: 0.7507 - val_loss: 0.1889

# %%
test_loss, test_acc = ann_model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7253 - loss: 0.1995
# Test accuracy: 0.7352732419967651

# %% [markdown]
# ### Accuracy Almost 73%
